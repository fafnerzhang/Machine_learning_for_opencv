# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import mixture
import cv2
# %matplotlib inline
duck=cv2.imread('duck_black.jpg')
plt.imshow(duck)
print(duck.shape)
# Out:
# (213, 427, 3)

# %%
gaussian=mixture.GaussianMixture(n_components=2,covariance_type='full')

# %%
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-26-4d813aafbb3b> in <module>
# ----> 1 gaussian.bic(duck)
#
# ~\Anaconda3\envs\opencv\lib\site-packages\sklearn\mixture\gaussian_mixture.py in bic(self, X)
#     739             The lower the better.
#     740         """
# --> 741         return (-2 * self.score(X) * X.shape[0] +
#     742                 self._n_parameters() * np.log(X.shape[0]))
#     743
#
# ~\Anaconda3\envs\opencv\lib\site-packages\sklearn\mixture\base.py in score(self, X, y)
#     352             Log likelihood of the Gaussian mixture given X.
#     353         """
# --> 354         return self.score_samples(X).mean()
#     355
#     356     def predict(self, X):
#
# ~\Anaconda3\envs\opencv\lib\site-packages\sklearn\mixture\base.py in score_samples(self, X)
#     333             Log probabilities of each data point in X.
#     334         """
# ...
