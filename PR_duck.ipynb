# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import mixture
import cv2
# %matplotlib inline
duck=cv2.imread('duck_black.jpg')
plt.imshow(duck)

# %%
non_duck=cv2.imread('duck.jpg')
plt.imshow(non_duck)

# %%
non_duck=cv2.cvtColor(non_duck,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(non_duck)

# %%
# Out:
# array([[ 85,  99, 114, ..., 247, 248, 249],
#        [ 84, 109, 127, ..., 248, 249, 250],
#        [ 90,  99, 102, ..., 248, 249, 250],
#        ...,
#        [ 99,  99, 100, ..., 124, 116, 110],
#        [110, 116, 121, ..., 112, 111, 111],
#        [106, 119, 132, ..., 110, 114, 117]], dtype=uint8)
